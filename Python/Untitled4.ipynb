# %%
l = int(input("input: "))
r = input("option: ")
def b():
    x = l
    z = 0
    b = 1
    while x > 0:
        y = x % 2
        z = z + (y * b)
        x = x // 2
        b = b * 10
    print(z)
def o():
    x = l
    z = 0
    b = 1
    while x > 0:
        y = x % 8
        z = z + (y * b)
        x = x // 8
        b = b * 10
    print(z)
def h():
    x = l
    z = 0
    b = 1
    
    while x > 0:
        y = x % 16
        z = z + (y * b)
        x = x // 16
        b = b * 10
        if x > 9:
            m = chr(y + 55)
    print(z,m)
    
if r == 'b' or 'B':
    b()
elif r == 'o' or "O":
    o()
elif r == 'h' or "H":
    h()
else:
    print("!!")
# Out:
# input: 150
# option: h
# 10010110
