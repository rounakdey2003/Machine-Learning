# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
pal = sns.color_palette()

data = pd.read_csv('Train.csv')

# %%
data
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# 1                    5                  216                2
# 2                    2                  183                4
# 3                    3                  176                4
# 4                    2                  184                3
# ...                ...                  ...              ...
# 10994                1                  252                5
# 10995                1                  232                5
# 10996                4                  242                5
# 10997                2                  223                6
# 10998                5                  155                5
#
#       Product_importance Gender  Discount_offered  Weight_in_gms  \
# 0                    low      F                44           1233
# 1                    low      M                59           3088
# 2                    low      M                48           3374
# 3                 medium      M                10           1177
# 4                 medium      F                46           2484
# ...                  ...    ...               ...            ...
# 10994             medium      F                 1           1538
# 10995             medium      F                 6           1247
# 10996                low      F                 4           1155
# 10997             medium      M                 2           1210
# 10998                low      F                 6           1639
#
#        Reached.on.Time_Y.N
# 0                        1
# 1                        1
# 2                        1
# 3                        1
# 4                        1
# ...                    ...
# 10994                    1
# 10995                    0
# 10996                    0
# 10997                    0
# 10998                    0
#
# [10999 rows x 12 columns]

# %%
plt.figure(figsize=(18, 10))
num_features = data.select_dtypes('number').drop('Reached.on.Time_Y.N', axis=1).columns.values

for i, num in enumerate(num_features):
    plt.subplot(2, 3, i+1)
    sns.histplot(data[num], color=pal[i])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41328\517875312.py in <module>
# ----> 1 plt.figure(figsize=(18, 10))
#       2 num_features = data.select_dtypes('number').drop('Reached.on.Time_Y.N', axis=1).columns.values
#       3
#       4 for i, num in enumerate(num_features):
#       5     plt.subplot(2, 3, i+1)
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=(4, 4))
sns.heatmap(data[data.select_dtypes('number').columns].corr(),
            square=True, cmap='seismic', cbar=False, annot=True, fmt='.2f', vmin=-1, vmax=1)
plt.show()

# %%
plt.figure(figsize=(14, 12))

cat_features = data.select_dtypes('object').columns.values

for i, cat in enumerate(cat_features):

    plt.subplot(2, 2, i+1)
    sns.histplot(data[cat], shrink=0.8, color=pal[i])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41328\1886520736.py in <module>
# ----> 1 plt.figure(figsize=(14, 12))
#       2
#       3 cat_features = data.select_dtypes('object').columns.values
#       4
#       5 for i, cat in enumerate(cat_features):
#
# NameError: name 'plt' is not defined
