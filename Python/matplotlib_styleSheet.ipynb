# %%
"""
===========================
Dark background style sheet
===========================
This example demonstrates the "dark_background" style, which uses white for
elements that are typically black (text, borders, etc). Note that not all plot
elements default to colors defined by an rc parameter.
"""
import numpy as np
import matplotlib.pyplot as plt


plt.style.use('dark_background')

fig, ax = plt.subplots()

L = 6
x = np.linspace(0, L)
ncolors = len(plt.rcParams['axes.prop_cycle'])
shift = np.linspace(0, L, ncolors, endpoint=False)
for s in shift:
    ax.plot(x, np.sin(x + s), 'o-')
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_title("'dark_background' style sheet")

plt.show()

# %%
"""
===========================
Dark background style sheet
===========================

This example demonstrates the "dark_background" style, which uses white for
elements that are typically black (text, borders, etc). Note that not all plot
elements default to colors defined by an rc parameter.

"""
import numpy as np
import matplotlib.pyplot as plt


plt.style.use('Solarize_Light2')

fig, ax = plt.subplots()

L = 5
B = -5
x = np.linspace(B, L)
ncolors = len(plt.rcParams['axes.prop_cycle'])
shift = np.linspace(B, L, ncolors, endpoint=False)
for s in shift:
    ax.plot(x, np.sin(x + s), 'o-')
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_title("'dark_background' style sheet")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# g:\My Drive\Siladitya Sir\Projects\Matplotlib\Matplotlib\matplotlib_styleSheet.ipynb Cell 2 in <cell line: 11>()
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/Siladitya%20Sir/Projects/Matplotlib/Matplotlib/matplotlib_styleSheet.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> """
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/Siladitya%20Sir/Projects/Matplotlib/Matplotlib/matplotlib_styleSheet.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> ===========================
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/Siladitya%20Sir/Projects/Matplotlib/Matplotlib/matplotlib_styleSheet.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> Dark background style sheet
#    (...)
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/Siladitya%20Sir/Projects/Matplotlib/Matplotlib/matplotlib_styleSheet.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a>
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/Siladitya%20Sir/Projects/Matplotlib/Matplotlib/matplotlib_styleSheet.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a> """
# ---> <a href='vscode-notebook-cell:/g%3A/My%20Drive/Siladitya%20Sir/Projects/Matplotlib/Matplotlib/matplotlib_styleSheet.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a> import numpy as np
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/Siladitya%20Sir/Projects/Matplotlib/Matplotlib/matplotlib_styleSheet.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a> import matplotlib.pyplot as plt
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/Siladitya%20Sir/Projects/Matplotlib/Matplotlib/matplotlib_styleSheet.ipynb#W1sZmlsZQ%3D%3D?line=14'>15</a> plt.style.use('Solarize_Light2')
#
# ModuleNotFoundError: No module named 'numpy'
