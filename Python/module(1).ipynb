# %%
def cal:
  a=input("First number: ")
  b=input("Second number: ")
  c=a+b
# Out:
#   File "<ipython-input-1-b3f020ebb591>", line 1
#     def cal:
#            ^
# SyntaxError: invalid syntax

# %%
import
